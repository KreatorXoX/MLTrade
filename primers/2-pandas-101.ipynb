# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
yf.pdr_override()
from pandas_datareader.data import DataReader

# %% [markdown]
# ### Extract and View Data

# %%
start_date = '2017-01-01'
end_date = '2022-06-01'
symbol ='ETH-USD'

df = DataReader(symbol,start_date,end_date)
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-09  308.644989  329.451996  307.056000  320.884003  320.884003
# 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
#
#                 Volume
# Date
# 2017-11-09   893249984
# 2017-11-10   885985984
# 2017-11-11   842300992
# 2017-11-12  1613479936
# 2017-11-13  1041889984

# %%
df.tail(2)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-05-30  1811.885986  2005.210815  1804.456055  1996.441284  1996.441284
# 2022-05-31  1996.408081  2005.490967  1932.352051  1942.328003  1942.328003
#
#                  Volume
# Date
# 2022-05-30  19580808705
# 2022-05-31  18363115560

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1665 entries, 2017-11-09 to 2022-05-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1665 non-null   float64
#  1   High       1665 non-null   float64
#  2   Low        1665 non-null   float64
#  3   Close      1665 non-null   float64
#  4   Adj Close  1665 non-null   float64
#  5   Volume     1665 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 91.1 KB

# %% [markdown]
# # Working with Returns

# %%
df['Returns'] = df['Close'].pct_change()

# we can drop or fill the NaN values
# df.fillna(0,inplace=True)

df.dropna(inplace=True)

df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
# 2017-11-15  337.963989  340.911987  329.812988  333.356995  333.356995
# 2017-11-16  333.442993  336.158997  323.605988  330.924011  330.924011
# 2017-11-17  330.166992  334.963989  327.523010  332.394012  332.394012
# 2017-11-18  331.980011  349.615997  327.687012  347.612000  347.612000
# 2017-11-19  347.401001  371.290985  344.739990  354.385986  354.385986
#
#                 Volume   Returns
# Date
# 2017-11-10   885985984 -0.067411
# 2017-11-11   842300992  0.051555
# 2017-11-12  1613479936 -0.021523
# 2017-11-13  1041889984  0.028606
# 2017-11-14  1069680000  0.066037
# 2017-11-15   722665984 -0.012659
# 2017-11-16   797254016 -0.007298
# 2017-11-17   621732992  0.004442
# 2017-11-18   649638976  0.045783
# 2017-11-19  1181529984  0.019487

# %%
# Calculating the log returns is the most accurate

df['log_returns'] = np.log(df['Close']/df['Close'].shift(1))
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
# 2017-11-15  337.963989  340.911987  329.812988  333.356995  333.356995
# 2017-11-16  333.442993  336.158997  323.605988  330.924011  330.924011
# 2017-11-17  330.166992  334.963989  327.523010  332.394012  332.394012
# 2017-11-18  331.980011  349.615997  327.687012  347.612000  347.612000
# 2017-11-19  347.401001  371.290985  344.739990  354.385986  354.385986
#
#                 Volume   Returns  log_returns
# Date
# 2017-11-10   885985984 -0.067411          NaN
# 2017-11-11   842300992  0.051555     0.050270
# 2017-11-12  1613479936 -0.021523    -0.021758
# 2017-11-13  1041889984  0.028606     0.028204
# 2017-11-14  1069680000  0.066037     0.063948
# 2017-11-15   722665984 -0.012659    -0.012740
# 2017-11-16   797254016 -0.007298    -0.007325
# 2017-11-17   621732992  0.004442     0.004432
# 2017-11-18   649638976  0.045783     0.044766
# 2017-11-19  1181529984  0.019487     0.019300

# %%
# Cumulative Sum Returns

df['l_returns_cumsum'] = df['log_returns'].cumsum()
df.head(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
#
#                 Volume   Returns  log_returns  l_returns_cumsum
# Date
# 2017-11-10   885985984 -0.067411          NaN               NaN
# 2017-11-11   842300992  0.051555     0.050270          0.050270
# 2017-11-12  1613479936 -0.021523    -0.021758          0.028512
# 2017-11-13  1041889984  0.028606     0.028204          0.056716
# 2017-11-14  1069680000  0.066037     0.063948          0.120664

# %%
# Normalize Log Returns
df['l_returns_normalized'] = np.exp(df['l_returns_cumsum']) - 1
df.fillna(0,inplace=True)
df.head(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
#
#                 Volume   Returns  log_returns  l_returns_cumsum  \
# Date
# 2017-11-10   885985984 -0.067411     0.000000          0.000000
# 2017-11-11   842300992  0.051555     0.050270          0.050270
# 2017-11-12  1613479936 -0.021523    -0.021758          0.028512
# 2017-11-13  1041889984  0.028606     0.028204          0.056716
# 2017-11-14  1069680000  0.066037     0.063948          0.120664
#
#             l_returns_normalized
# Date
# 2017-11-10              0.000000
# 2017-11-11              0.051555
# 2017-11-12              0.028922
# 2017-11-13              0.058355
# 2017-11-14              0.128246
